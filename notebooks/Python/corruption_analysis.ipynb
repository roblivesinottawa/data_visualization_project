# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid")

# %%
df = pd.read_csv("../../data/Economist_Data.csv")

# %%
df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head(15)
# Out:
#         Country  HDI.Rank    HDI  CPI             Region
# 0   Afghanistan       172  0.398  1.5       Asia Pacific
# 1       Albania        70  0.739  3.1  East EU Cemt Asia
# 2       Algeria        96  0.698  2.9               MENA
# 3        Angola       148  0.486  2.0                SSA
# 4     Argentina        45  0.797  3.0           Americas
# 5       Armenia        86  0.716  2.6  East EU Cemt Asia
# 6     Australia         2  0.929  8.8       Asia Pacific
# 7       Austria        19  0.885  7.8       EU W. Europe
# 8    Azerbaijan        91  0.700  2.4  East EU Cemt Asia
# 9       Bahamas        53  0.771  7.3           Americas
# 10      Bahrain        42  0.806  5.1               MENA
# 11   Bangladesh       146  0.500  2.7       Asia Pacific
# 12     Barbados        47  0.793  7.8           Americas
# 13      Belarus        65  0.756  2.4  East EU Cemt Asia
# 14      Belgium        18  0.886  7.5       EU W. Europe

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="CPI", y="HDI", data=df, hue="Region")
# Out:
# <AxesSubplot:xlabel='CPI', ylabel='HDI'>
